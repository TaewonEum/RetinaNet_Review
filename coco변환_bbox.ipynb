# %%
#dataloader
from __future__ import print_function, division
import sys
import os
import torch
import glob
import numpy as np
import random
import csv
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.patches as patches

import torch.nn as nn
from torch.optim.lr_scheduler import ReduceLROnPlateau
import torchvision
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
from torch.utils.data.sampler import Sampler
import albumentations
import albumentations.pytorch

from pycocotools.coco import COCO

import skimage.io
import skimage.transform
import skimage.color
import skimage

from PIL import Image

# %%
# utils
import time
import shutil
import numpy as np
from random import sample
from tqdm import tqdm
import json

# %%
#test data 경로
path='C:/Users/user/Desktop/sample_flexink'

# %%
# new data path
save_path='C:/Users/user/Desktop'

# %%
classes=['halibut'] #탐지할 클래스명

# %%
os.listdir(path)
# Out:
# ['01_원천데이터', '02_라벨링데이터']

# %% [markdown]
# # dataset 경로 저장(전체 데이터 저장 후 TVT)

# %%
# 파일 리스트화
img_list=[]
lab_list=[]


img_path=glob.glob(path+'/'+'01_원천데이터'+'/*')
lab_path=glob.glob(path+'/'+'02_라벨링데이터'+'/*')
for i in range(len(img_path)):
    img_path[i]=img_path[i].replace('\\','/')
    lab_path[i]=lab_path[i].replace('\\','/')
img_list.extend(img_path)
lab_list.extend(lab_path)

# %%
print(len(img_list)) #이미지 파일명
print(len(lab_list)) #라벨링 파일명
# Out:
# 100
# 100

# %%
img_list[0]
# Out:
# 'C:/Users/user/Desktop/sample_flexink/01_원천데이터/SA12_T01_FR_000002.jpg'

# %%
lab_list[0]
# Out:
# 'C:/Users/user/Desktop/sample_flexink/02_라벨링데이터/SA12_T01_FR_000002.json'

# %% [markdown]
# # TVT변환 진행
#
# ### 1. 새 폴더 생성
#
# ### 2. 이미지, 라벨링 8:1:1 비율로 분할 진행

# %% [markdown]
# # 1.새 폴더 생성

# %%
def createFolder(save_dir):
    try:
        for tvt in ['train', 'test', 'valid']:
            for IL in ['images', 'labels']:
                dir = save_dir + '/' + 'coco_flexing' + '/' + tvt + '/' + IL 
                if not os.path.exists(dir):
                    os.makedirs(dir)
                else:
                    print('Folder has already been created')
    except OSError:
        print('Error: Creating directory. ' + save_dir)

# %%
createFolder(save_dir=save_path) #바탕화면에 새 폴더 생성->해당 폴더에 TVT나누어 이미지 라벨링 파일 저장 해야함
# Out:
# Folder has already been created
# Folder has already been created
# Folder has already been created
# Folder has already been created
# Folder has already been created
# Folder has already been created

# %% [markdown]
# # 2. 이미지, 라벨링 8:1:1 비율로 분할 진행

# %%
def get_tv_idx(tl, p = 0.8, m = 0.5):
    total_idx = range(tl)
    train_idx = sample(total_idx, int(tl * p)) #전체에서 80% 데이터 추출
    temp_idx = set(total_idx) - set(train_idx) #전체 인덱스값에서 트레인 데이터에 해당하는 인덱스 제거
    valid_idx = sample(temp_idx, int(len(temp_idx) * m)) #남은 인덱스값에서 50%추출->전체데이터에서 10%추출
    test_idx = set(temp_idx) - set(valid_idx) #전체에서 10%데이터 추출

    return train_idx, valid_idx, list(test_idx)

# %% [markdown]
# # 데이터 분할(index)

# %%
train_idx, valid_idx, test_idx = get_tv_idx(len(img_list))

# %%
print(len(train_idx))
print(len(valid_idx))
print(len(test_idx))
# Out:
# 80
# 10
# 10

# %% [markdown]
# # TVT별 이미지, 라벨링 데이터 경로 추출

# %%
train_img_list = [img_list[idx] for idx in train_idx]
train_lab_list= [lab_list[idx] for idx in train_idx]
valid_img_list = [img_list[idx] for idx in valid_idx]
valid_lab_list=[lab_list[idx] for idx in valid_idx]
test_img_list = [img_list[idx] for idx in test_idx]
test_lab_list= [lab_list[idx] for idx in test_idx]

# %% [markdown]
# # COCO dataset 형식 작성
#
# ## RetinaNet은 Train, Valid, Test 당 각각 한개의 annotations 파일이 필요함

# %%
coco_data = {
    "info": {
        "year": "2023",
        "version": "1.0",
        "description": "MYUNGSUN",
        "contributor": "",
        "url": "MYUNGSUN",
        "date_created": "2022-11-16 09:27:18"
    },
    "licenses": [
        {
            "id": 1,
            "url": "MYUNGSUN",
            "name": "Image of halibut"
        }
    ],
    "categories": [
        {
            "id": 0,
            "name": "background",
            "supercategory": "none"
        },
        {
            "id": 1,
            "name": "halibut",
            "supercategory": "none"
        }
    ],
    "images": [],
    "annotations": []
}

# 이미지 및 객체 ID 변수 초기화
image_id = 0
annotation_id = 0

# %%
for label_file in lab_list: 
    with open(label_file, "r",encoding='UTF-8') as f:
        label_data = json.load(f)
    
    # coco_dataset의 images항목 채우기
    image_info=label_data['IMAGE']
    image_info['id']=image_id
    coco_data['images'].append(image_info)
    
    # annotations 항목 채우기 객체 정보 추가
    annotation_info = label_data["ANNOTATION_INFO"]
    for annotation in annotation_info:
        annotation["id"] = annotation_id
        annotation["image_id"] = image_id
        coco_data["annotations"].append(annotation)
        annotation_id+=1
    image_id += 1 #image_id +1씩

# %%
print(len(coco_data['images']))
print(len(coco_data['annotations']))
# Out:
# 2065
# 20294

# %%
#이미지 라벨링 파일 변경
for image in coco_data['images']:
    image['width']=image.pop('WIDTH')
    image['height']=image.pop('HEIGHT')
    image['file_name']=image.pop('IMAGE_FILE_NAME')

# %%
for annotation in coco_data['annotations']:
    if annotation['LIFECYCLE'] == 'LA' and annotation['DISEASES'] == 0:
        annotation['category_id'] = 1
    elif annotation['LIFECYCLE'] == 'LA' and annotation['DISEASES'] == 1:
        annotation['category_id'] = 2
    ### 좌표값 반환
    x=annotation['XTL']
    y=annotation['YTL']
    width=annotation['XBR']-annotation['XTL']
    height=annotation['YBR']-annotation['YTL']
    annotation['bbox']=[x,y,width,height]
    #좌표값 삭제
    annotation.pop('XTL')
    annotation.pop('YTL')
    annotation.pop('XBR')
    annotation.pop('YBR')
    #필요없는 항목 삭제
    annotation.pop('ID')
    annotation.pop('SPECIES')
    annotation.pop('LIFECYCLE')
    annotation.pop('DISEASES')
    annotation.pop('TYPE')
    annotation.pop('CROWDSOURSING_OPERATION_ALTERNATIVE')
    # area 계산
    bbox=annotation['bbox']
    area = bbox[2] * bbox[3]
    annotation['area']=area
    annotation['segmentation']=[]
    annotation['iscrowd']=0

# %%
output_file = "instances_train.json"
with open(train_path+'/'+'annotations'+'/'+output_file, "w") as f:
    json.dump(coco_data, f)

# %% [markdown]
# # Vaild COCO dataset

# %%
# 파일 리스트화
val_img_list=[]
val_lab_list=[]

for i in classes:
    val_img=glob.glob(valid_path+'/'+'images'+'/'+i+'/*')
    val_lab=glob.glob(valid_path+'/'+'annotations'+'/'+i+'/*')
    for j in range(len(val_img)):
        val_img[j]=val_img[j].replace('\\','/')
        val_lab[j]=val_lab[j].replace('\\','/')
    val_img_list.extend(val_img)
    val_lab_list.extend(val_lab)

# %%
print(len(val_img_list))
print(len(val_lab_list))
# Out:
# 2065
# 2065

# %%
coco_data_val = {
    "info": {
        "year": "2023",
        "version": "1.0",
        "description": "Exported from labelon.kr",
        "contributor": "",
        "url": "https://www.labelon.kr",
        "date_created": "2022-11-16 09:27:18"
    },
    "licenses": [
        {
            "id": 1,
            "url": "https://images.labelon.kr",
            "name": "Image of honeybee disease diagnosis"
        }
    ],
    "categories": [
        {
            "id": 0,
            "name": "background",
            "supercategory": "none"
        },
        {
            "id": 1,
            "name": "LA",
            "supercategory": "none"
        },
        {
            "id": 2,
            "name": "disease",
            "supercategory": "none"
        }
    ],
    "images": [],
    "annotations": []
}

# 이미지 및 객체 ID 변수 초기화
image_id = 0
annotation_id = 0

# %%
for label_file in val_lab_list:
    with open(label_file, "r",encoding='UTF-8') as f:
        label_data = json.load(f)
    
    # coco_dataset의 images항목 채우기
    image_info=label_data['IMAGE']
    image_info['id']=image_id
    coco_data_val['images'].append(image_info)
    
    # annotations 항목 채우기 객체 정보 추가
    annotation_info = label_data["ANNOTATION_INFO"]
    for annotation in annotation_info:
        annotation["id"] = annotation_id
        annotation["image_id"] = image_id
        coco_data_val["annotations"].append(annotation)
        annotation_id+=1
    image_id += 1 #image_id +1씩

# %%
print(len(coco_data_val['images']))
print(len(coco_data_val['annotations']))
# Out:
# 2065
# 20258

# %%
#이미지 라벨링 파일 변경
for image in coco_data_val['images']:
    image['width']=image.pop('WIDTH')
    image['height']=image.pop('HEIGHT')
    image['file_name']=image.pop('IMAGE_FILE_NAME')

# %%
for annotation in coco_data_val['annotations']:
    if annotation['LIFECYCLE'] == 'LA' and annotation['DISEASES'] == 0:
        annotation['category_id'] = 1
    elif annotation['LIFECYCLE'] == 'LA' and annotation['DISEASES'] == 1:
        annotation['category_id'] = 2
    ### 좌표값 반환
    x=annotation['XTL']
    y=annotation['YTL']
    width=annotation['XBR']-annotation['XTL']
    height=annotation['YBR']-annotation['YTL']
    annotation['bbox']=[x,y,width,height]
    #좌표값 삭제
    annotation.pop('XTL')
    annotation.pop('YTL')
    annotation.pop('XBR')
    annotation.pop('YBR')
    #필요없는 항목 삭제
    annotation.pop('ID')
    annotation.pop('SPECIES')
    annotation.pop('LIFECYCLE')
    annotation.pop('DISEASES')
    annotation.pop('TYPE')
    annotation.pop('CROWDSOURSING_OPERATION_ALTERNATIVE')
    # area 계산
    bbox=annotation['bbox']
    area = bbox[2] * bbox[3]
    annotation['area']=area
    annotation['segmentation']=[]
    annotation['iscrowd']=0

# %%
output_file = "instances_val.json"
with open(valid_path+'/'+'annotations'+'/'+output_file, "w") as f:
    json.dump(coco_data_val, f)

# %% [markdown]
# # Test COCO build

# %%
# 파일 리스트화
test_img_list=[]
test_lab_list=[]

for i in classes:
    test_img=glob.glob(test_path+'/'+'images'+'/'+i+'/*')
    test_lab=glob.glob(test_path+'/'+'annotations'+'/'+i+'/*')
    for j in range(len(test_img)):
        test_img[j]=test_img[j].replace('\\','/')
        test_lab[j]=test_lab[j].replace('\\','/')
    test_img_list.extend(test_img)
    test_lab_list.extend(test_lab)

# %%
len(test_img_list)
# Out:
# 450

# %%
test_img_list
# Out:
# ['C:/Users/user/Desktop/bee_disease/test/images/Larva/01_1_R_LA_NA_20
jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0094.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0098.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0099.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0110.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0111.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0118.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0122.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0123.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0126.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0128.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0138.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0147.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0150.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0165.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0168.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0176.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0179.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0180.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0181.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0183.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0186.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0188.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0192.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0195.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0198.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0207.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0211.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0213.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0218.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0224.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0225.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0226.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0229.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0230.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0232.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0239.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0240.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0241.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0245.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0250.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0253.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0254.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0257.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0259.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0264.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0266.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0267.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0269.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0278.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0279.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0286.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0294.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0299.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0308.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0311.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0314.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0315.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0316.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0319.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0321.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0323.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0331.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0338.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0341.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0344.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0353.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0356.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0368.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0372.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0375.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0382.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0385.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0386.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0401.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0406.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0423.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0425.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0433.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0439.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0441.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0445.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0449.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0453.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0455.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0456.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0458.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0460.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0461.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0463.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0467.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0470.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0472.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0479.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0485.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0486.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0494.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0496.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0501.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0503.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0508.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0514.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0515.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0518.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0523.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0527.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0528.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0530.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0531.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0532.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0533.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0534.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0541.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0542.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0544.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0545.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0549.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0551.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0552.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0555.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0556.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0570.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0575.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0582.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0584.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0586.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0587.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0590.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0591.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0595.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0599.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0600.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0602.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0605.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0607.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0608.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0609.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0612.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0617.jpg',
#  'C:/Users/user/Desktop/bee_disease/test/images/disease/06_1_R_AA_NA_20221031_02_0622.jpg']

# %%
coco_data_test = {
    "info": {
        "year": "2023",
        "version": "1.0",
        "description": "Exported from labelon.kr",
        "contributor": "",
        "url": "https://www.labelon.kr",
        "date_created": "2022-11-16 09:27:18"
    },
    "licenses": [
        {
            "id": 1,
            "url": "https://images.labelon.kr",
            "name": "Image of honeybee disease diagnosis"
        }
    ],
    "categories": [
        {
            "id": 0,
            "name": "background",
            "supercategory": "none"
        },
        {
            "id": 1,
            "name": "LA",
            "supercategory": "none"
        },
        {
            "id": 2,
            "name": "disease",
            "supercategory": "none"
        }
    ],
    "images": [],
    "annotations": []
}

# 이미지 및 객체 ID 변수 초기화
image_id = 0
annotation_id = 0

# %%
for label_file in test_lab_list:
    with open(label_file, "r",encoding='UTF-8') as f:
        label_data = json.load(f)
    
    # coco_dataset의 images항목 채우기
    image_info=label_data['IMAGE']
    image_info['id']=image_id
    coco_data_test['images'].append(image_info)
    
    # annotations 항목 채우기 객체 정보 추가
    annotation_info = label_data["ANNOTATION_INFO"]
    for annotation in annotation_info:
        annotation["id"] = annotation_id
        annotation["image_id"] = image_id
        coco_data_test["annotations"].append(annotation)
        annotation_id+=1
    image_id += 1 #image_id +1씩

# %%
coco_data_test
# Out:
# {'info': {'year': '2023',
#   'version': '1.0',
#   'description': 'Exported from labelon.kr',
#   'contributor': '',
#   'url': 'https://www.labelon.kr',
#   'date_created': '2022-11-16 09:27:18'},
#  'licenses': [{'id': 1,
#    'url': 'https://images.labelon.kr',
#    'name': 'Image of honeybee disease diagnosis'}],
#  'categories': [{'id': 0, 'name': 'background', 'supercategory': 'none'},
#   {'id': 1, 'name': 'LA', 'supercategory': 'none'},
#   {'id': 2, 'name': 'disease', 'supercategory': 'none'}],
#  'images': [{'IMAGE_URL': 'https://images.labelon.kr/2022/07/14/7fcea8fc45e541e4b4daf6c2eeaa23e4.jpg',
#    'IMAGE_FILE_NAME': '01_1_R_LA_NA_20220707_01_053.jpg',
#    'WIDTH': 1920,
#    'HEIGHT': 1080,
#    'id': 0},
#   {'IMAGE_URL': 'https://images.labelon.kr/2022/07/14/07f287cb02cd4e4dad0b8df5283d7848.jpg',
#    'IMAGE_FILE_NAME': '01_1_R_LA_NA_20220707_02_248.jpg',
#    'WIDTH': 1920,
#    'HEIGHT': 1080,
#    'id':

#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 938,
#    'image_id': 119},
#   {'ID': 123618853,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 776,
#    'YTL': 675,
#    'XBR': 866,
#    'YBR': 767,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 939,
#    'image_id': 119},
#   {'ID': 123618854,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 192,
#    'YTL': 875,
#    'XBR': 280,
#    'YBR': 979,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 940,
#    'image_id': 119},
#   {'ID': 123637500,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 776,
#    'YTL': 672,
#    'XBR': 866,
#    'YBR': 765,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 941,
#    'image_id': 120},
#   {'ID': 123637501,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 193,
#    'YTL': 875,
#    'XBR': 280,
#    'YBR': 978,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 942,
#    'image_id': 120},
#   {'ID': 123637502,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 186,
#    'YTL': 491,
#    'XBR': 270,
#    'YBR': 569,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 943,
#    'image_id': 120},
#   {'ID': 123637503,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 179,
#    'YTL': 99,
#    'XBR': 274,
#    'YBR': 172,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 944,
#    'image_id': 120},
#   {'ID': 123637504,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 469,
#    'YTL': 181,
#    'XBR': 559,
#    'YBR': 273,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 945,
#    'image_id': 120},
#   {'ID': 123637505,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 753,
#    'YTL': 78,
#    'XBR': 852,
#    'YBR': 166,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 946,
#    'image_id': 120},
#   {'ID': 123616859,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 178,
#    'YTL': 98,
#    'XBR': 274,
#    'YBR': 173,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 947,
#    'image_id': 121},
#   {'ID': 123616860,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 469,
#    'YTL': 181,
#    'XBR': 559,
#    'YBR': 272,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 948,
#    'image_id': 121},
#   {'ID': 123616861,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 753,
#    'YTL': 78,
#    'XBR': 853,
#    'YBR': 169,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 949,
#    'image_id': 121},
#   {'ID': 123616862,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 186,
#    'YTL': 489,
#    'XBR': 273,
#    'YBR': 568,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 950,
#    'image_id': 121},
#   {'ID': 123616863,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 776,
#    'YTL': 673,
#    'XBR': 866,
#    'YBR': 765,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 951,
#    'image_id': 121},
#   {'ID': 123616864,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 193,
#    'YTL': 874,
#    'XBR': 276,
#    'YBR': 979,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 952,
#    'image_id': 121},
#   {'ID': 123753525,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 178,
#    'YTL': 99,
#    'XBR': 277,
#    'YBR': 173,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 953,
#    'image_id': 122},
#   {'ID': 123753526,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 469,
#    'YTL': 181,
#    'XBR': 559,
#    'YBR': 272,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 954,
#    'image_id': 122},
#   {'ID': 123753527,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 751,
#    'YTL': 78,
#    'XBR': 852,
#    'YBR': 168,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 955,
#    'image_id': 122},
#   {'ID': 123753528,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 776,
#    'YTL': 673,
#    'XBR': 866,
#    'YBR': 766,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 956,
#    'image_id': 122},
#   {'ID': 123753529,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 185,
#    'YTL': 488,
#    'XBR': 278,
#    'YBR': 569,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 957,
#    'image_id': 122},
#   {'ID': 123753530,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 193,
#    'YTL': 875,
#    'XBR': 283,
#    'YBR': 980,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 958,
#    'image_id': 122},
#   {'ID': 123716285,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 752,
#    'YTL': 77,
#    'XBR': 858,
#    'YBR': 173,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 959,
#    'image_id': 123},
#   {'ID': 123716286,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 468,
#    'YTL': 179,
#    'XBR': 562,
#    'YBR': 272,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 960,
#    'image_id': 123},
#   {'ID': 123716287,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 184,
#    'YTL': 488,
#    'XBR': 277,
#    'YBR': 572,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 961,
#    'image_id': 123},
#   {'ID': 123716288,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 776,
#    'YTL': 672,
#    'XBR': 866,
#    'YBR': 766,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 962,
#    'image_id': 123},
#   {'ID': 123716289,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 193,
#    'YTL': 877,
#    'XBR': 280,
#    'YBR': 978,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 963,
#    'image_id': 123},
#   {'ID': 123716290,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 175,
#    'YTL': 97,
#    'XBR': 275,
#    'YBR': 175,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 964,
#    'image_id': 123},
#   {'ID': 123636555,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 177,
#    'YTL': 98,
#    'XBR': 274,
#    'YBR': 173,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 965,
#    'image_id': 124},
#   {'ID': 123636556,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 468,
#    'YTL': 180,
#    'XBR': 558,
#    'YBR': 273,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 966,
#    'image_id': 124},
#   {'ID': 123636557,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 754,
#    'YTL': 77,
#    'XBR': 852,
#    'YBR': 167,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 967,
#    'image_id': 124},
#   {'ID': 123636558,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 186,
#    'YTL': 482,
#    'XBR': 273,
#    'YBR': 570,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 968,
#    'image_id': 124},
#   {'ID': 123636559,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 192,
#    'YTL': 876,
#    'XBR': 280,
#    'YBR': 981,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 969,
#    'image_id': 124},
#   {'ID': 123636560,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 776,
#    'YTL': 673,
#    'XBR': 865,
#    'YBR': 766,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 970,
#    'image_id': 124},
#   {'ID': 123692977,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 178,
#    'YTL': 99,
#    'XBR': 275,
#    'YBR': 173,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 971,
#    'image_id': 125},
#   {'ID': 123692978,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 755,
#    'YTL': 79,
#    'XBR': 855,
#    'YBR': 168,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 972,
#    'image_id': 125},
#   {'ID': 123692979,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 470,
#    'YTL': 182,
#    'XBR': 563,
#    'YBR': 272,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 973,
#    'image_id': 125},
#   {'ID': 123692980,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 186,
#    'YTL': 490,
#    'XBR': 274,
#    'YBR': 569,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 974,
#    'image_id': 125},
#   {'ID': 123692981,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 776,
#    'YTL': 674,
#    'XBR': 870,
#    'YBR': 766,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 975,
#    'image_id': 125},
#   {'ID': 123692982,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 195,
#    'YTL': 877,
#    'XBR': 280,
#    'YBR': 981,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 976,
#    'image_id': 125},
#   {'ID': 123692983,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 337,
#    'YTL': 765,
#    'XBR': 459,
#    'YBR': 884,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 977,
#    'image_id': 125},
#   {'ID': 123692984,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 1464,
#    'YTL': 472,
#    'XBR': 1538,
#    'YBR': 556,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 978,
#    'image_id': 125},
#   {'ID': 123692985,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 470,
#    'YTL': 961,
#    'XBR': 578,
#    'YBR': 1074,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 979,
#    'image_id': 125},
#   {'ID': 123692986,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 1698,
#    'YTL': 847,
#    'XBR': 1794,
#    'YBR': 951,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 980,
#    'image_id': 125},
#   {'ID': 123714350,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 751,
#    'YTL': 78,
#    'XBR': 855,
#    'YBR': 168,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 981,
#    'image_id': 126},
#   {'ID': 123714352,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 468,
#    'YTL': 182,
#    'XBR': 559,
#    'YBR': 272,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 982,
#    'image_id': 126},
#   {'ID': 123714354,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 177,
#    'YTL': 101,
#    'XBR': 275,
#    'YBR': 181,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 983,
#    'image_id': 126},
#   {'ID': 123714356,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 183,
#    'YTL': 483,
#    'XBR': 272,
#    'YBR': 574,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 984,
#    'image_id': 126},
#   {'ID': 123714357,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 192,
#    'YTL': 877,
#    'XBR': 282,
#    'YBR': 978,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 985,
#    'image_id': 126},
#   {'ID': 123714359,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 775,
#    'YTL': 673,
#    'XBR': 866,
#    'YBR': 766,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 986,
#    'image_id': 126},
#   {'ID': 123686057,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 777,
#    'YTL': 673,
#    'XBR': 865,
#    'YBR': 766,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 987,
#    'image_id': 127},
#   {'ID': 123686058,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 194,
#    'YTL': 876,
#    'XBR': 279,
#    'YBR': 980,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 988,
#    'image_id': 127},
#   {'ID': 123686059,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 186,
#    'YTL': 489,
#    'XBR': 272,
#    'YBR': 569,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 989,
#    'image_id': 127},
#   {'ID': 123686060,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 470,
#    'YTL': 178,
#    'XBR': 559,
#    'YBR': 272,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 990,
#    'image_id': 127},
#   {'ID': 123686061,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 178,
#    'YTL': 98,
#    'XBR': 274,
#    'YBR': 174,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 991,
#    'image_id': 127},
#   {'ID': 123686062,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 753,
#    'YTL': 78,
#    'XBR': 850,
#    'YBR': 167,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 992,
#    'image_id': 127},
#   {'ID': 123739812,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 777,
#    'YTL': 674,
#    'XBR': 866,
#    'YBR': 764,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 993,
#    'image_id': 128},
#   {'ID': 123739813,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 195,
#    'YTL': 877,
#    'XBR': 278,
#    'YBR': 979,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 994,
#    'image_id': 128},
#   {'ID': 123739814,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 186,
#    'YTL': 485,
#    'XBR': 273,
#    'YBR': 567,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 995,
#    'image_id': 128},
#   {'ID': 123739815,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 472,
#    'YTL': 183,
#    'XBR': 559,
#    'YBR': 271,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 996,
#    'image_id': 128},
#   {'ID': 123739816,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 181,
#    'YTL': 100,
#    'XBR': 275,
#    'YBR': 173,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 997,
#    'image_id': 128},
#   {'ID': 123739817,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 753,
#    'YTL': 79,
#    'XBR': 852,
#    'YBR': 164,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 998,
#    'image_id': 128},
#   {'ID': 123731751,
#    'SPECIES': 'NA',
#    'LIFECYCLE': 'LA',
#    'DISEASES': 1,
#    'TYPE': 'Bounding Box',
#    'XTL': 195,
#    'YTL': 875,
#    'XBR': 279,
#    'YBR': 980,
#    'CROWDSOURSING_OPERATION_ALTERNATIVE': 'Y',
#    'id': 999,
#    'image_id': 129},
#   ...]}

# %%
#이미지 라벨링 파일 변경
for image in coco_data_test['images']:
    image['width']=image.pop('WIDTH')
    image['height']=image.pop('HEIGHT')
    image['file_name']=image.pop('IMAGE_FILE_NAME')

# %%
for annotation in coco_data_test['annotations']:
    if annotation['LIFECYCLE'] == 'LA' and annotation['DISEASES'] == 0:
        annotation['category_id'] = 1
    elif annotation['LIFECYCLE'] == 'LA' and annotation['DISEASES'] == 1:
        annotation['category_id'] = 2
    ### 좌표값 반환
    x=annotation['XTL']
    y=annotation['YTL']
    width=annotation['XBR']-annotation['XTL']
    height=annotation['YBR']-annotation['YTL']
    annotation['bbox']=[x,y,width,height]
    #좌표값 삭제
    annotation.pop('XTL')
    annotation.pop('YTL')
    annotation.pop('XBR')
    annotation.pop('YBR')
    #필요없는 항목 삭제
    annotation.pop('ID')
    annotation.pop('SPECIES')
    annotation.pop('LIFECYCLE')
    annotation.pop('DISEASES')
    annotation.pop('TYPE')
    annotation.pop('CROWDSOURSING_OPERATION_ALTERNATIVE')
    # area 계산
    bbox=annotation['bbox']
    area = bbox[2] * bbox[3]
    annotation['area']=area
    annotation['segmentation']=[]
    annotation['iscrowd']=0

# %%
output_file = "instances_test.json"
with open(test_path+'/'+'annotations'+'/'+output_file, "w") as f:
    json.dump(coco_data_test, f)
